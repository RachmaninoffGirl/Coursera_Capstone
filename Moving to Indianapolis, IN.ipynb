# %% [markdown]
# Let's begin by finding the top five safest zip codes/ neighborhoods in Indianapolis. To do this, I will be using a neighborhood crime data website and scraping information using Beautiful Soup.

# %%
# !pip install beautifulsoup4

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url='https://www.neighborhoodscout.com/in/indianapolis/crime'

# %%
website_url=requests.get('https://www.neighborhoodscout.com/in/indianapolis/crime').text

# %%
soup = BeautifulSoup(website_url,"lxml")
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- START -->
#   <meta charset="utf-8"/>
#   <title>
#    Indianapolis Crime Rates and Statistics - NeighborhoodScout
#   </title>
#   <link href="/favicon.ico" rel="icon" type="image/x-icon"/>
#   <meta content="Exclusive crime heat map and statistics for neighborhoods within Indianapolis, IN. Crime forecast reports available by address." name="description"/>
#   <link href="https://www.neighborhoodscout.com/in/indianapolis/crime" rel="canonical"/>
#   <meta content="width=device-width, initial-scale=1, minimum-scale=1, maximum-scale=1" name="viewport"/>
#   <meta content="ie=edge" http-equiv="x-ua-compatible"/>
#   <script type="text/javascript">
#    window.NREUM||(NREUM={});NREUM.info={"beacon":"bam.nr-data.net","errorBeacon":"bam.nr-data.net","licenseKey":"4c68a6d35e","applicationID":"36561052","transactionName":"ewpZQUBeWA9cE0kAUEwMUkYdUkYKVAQ=","queueTime":0,"applicationTime":130,"agent":""}
#   </script>
# ...

# %%
table = soup.find("div",{"class":"maplite-links hidden-md-down slide-out active"})

# %%
table
# Out:
# <div class="maplite-links hidden-md-down slide-out active" id="sliderLinks">
# <h2>Safest Indianapolis neighborhoods</h2>
# <ol>
# <li class="maplite-links-link truncate" data-id="24822" id="maplite-links-24822"><a href="/in/indianapolis/promontory-rd#crime">Promontory Rd / Old Stone Dr</a></li>
# <li class="maplite-links-link truncate" data-id="24819" id="maplite-links-24819"><a href="/in/indianapolis/96th-fall#crime">E 96th St / Fall Creek Rd</a></li>
# <li class="maplite-links-link truncate" data-id="24974" id="maplite-links-24974"><a href="/in/indianapolis/acton#crime">Acton / Charle Sumac Estates</a></li>
# <li class="maplite-links-link truncate" data-id="24976" id="maplite-links-24976"><a href="/in/indianapolis/franklin-edgewood#crime">S Franklin Rd / E Edgewood Ave</a></li>
# <li class="maplite-links-link truncate" data-id="24765" id="maplite-links-24765"><a href="/in/indianapolis/56th-st#crime">W 56th St / Dandy Trl</a></li>
# ...

# %%
neighborhoods = table.text

# %%
nay=neighborhoods.split('\n')

# %%
nay
# Out:
# ['',
#  'Safest Indianapolis neighborhoods',
#  '',
#  'Promontory Rd / Old Stone Dr',
#  'E 96th St / Fall Creek Rd',
#  'Acton / Charle Sumac Estates',
#  'S Franklin Rd / E Edgewood Ave',
#  'W 56th St / Dandy Trl',
#  'S Arlington Ave / Shelbyville Rd',
#  'Traders Point',
#  'Bridgeport',
#  'Fairwood Hills',
#  'Butler U / N Meridian St',
#  '',
#  '',
#  '',
#  '',
#  '']

# %%
import pandas as pd

# %%
nay1=pd.DataFrame(nay)

# %%
nay1
# Out:
#                                     0
# 0
# 1   Safest Indianapolis neighborhoods
# 2
# 3        Promontory Rd / Old Stone Dr
# 4           E 96th St / Fall Creek Rd
# 5        Acton / Charle Sumac Estates
# 6      S Franklin Rd / E Edgewood Ave
# 7               W 56th St / Dandy Trl
# 8    S Arlington Ave / Shelbyville Rd
# 9                       Traders Point
# 10                         Bridgeport
# 11                     Fairwood Hills
# 12           Butler U / N Meridian St
# 13
# 14
# 15
# 16
# 17

# %%
nay2=nay1.drop(nay1.index[[0,1,2,3,13,14,15,16,17]])

# %%
nay2
# Out:
#                                    0
# 4          E 96th St / Fall Creek Rd
# 5       Acton / Charle Sumac Estates
# 6     S Franklin Rd / E Edgewood Ave
# 7              W 56th St / Dandy Trl
# 8   S Arlington Ave / Shelbyville Rd
# 9                      Traders Point
# 10                        Bridgeport
# 11                    Fairwood Hills
# 12          Butler U / N Meridian St

# %% [markdown]
# After looking it up, I found that the Zipcodes for the Neighborhoods are:
#
# 46256
#
# 46259
#
# 46259
#
# 46234
#
# 46237
#
# 46278
#
# 46231
#
# 46256
#
# 46202

# %%
Zipcodes= [46256, 46259, 46259, 46234, 46237, 46278, 46231, 46256, 46202]

# %%
nay2['Zipcodes']=Zipcodes

# %%
nay2
# Out:
#                                    0  Zipcodes
# 4          E 96th St / Fall Creek Rd     46256
# 5       Acton / Charle Sumac Estates     46259
# 6     S Franklin Rd / E Edgewood Ave     46259
# 7              W 56th St / Dandy Trl     46234
# 8   S Arlington Ave / Shelbyville Rd     46237
# 9                      Traders Point     46278
# 10                        Bridgeport     46231
# 11                    Fairwood Hills     46256
# 12          Butler U / N Meridian St     46202

# %% [markdown]
# Let's take out Franklin since they are tied.

# %%
nay3=nay2.drop(nay2.index[[2]])

# %%
nay3
# Out:
#                                    0  Zipcodes
# 4          E 96th St / Fall Creek Rd     46256
# 5       Acton / Charle Sumac Estates     46259
# 7              W 56th St / Dandy Trl     46234
# 8   S Arlington Ave / Shelbyville Rd     46237
# 9                      Traders Point     46278
# 10                        Bridgeport     46231
# 11                    Fairwood Hills     46256
# 12          Butler U / N Meridian St     46202

# %% [markdown]
# Now let's convert it to the top 5 safest neighborhoods.

# %%
SafestFive=nay3.drop(nay3.index[[5,6,7]])

# %%
SafestFive
# Out:
#                                   0  Zipcodes
# 4         E 96th St / Fall Creek Rd     46256
# 5      Acton / Charle Sumac Estates     46259
# 7             W 56th St / Dandy Trl     46234
# 8  S Arlington Ave / Shelbyville Rd     46237
# 9                     Traders Point     46278

# %% [markdown]
# Now, let's find the latitude, longitude of these zipcodes with the csv I downloaded from a Zip Code database.

# %%
# The code was removed by Watson Studio for sharing.
# Out:
#      Zip          City State   Latitude  Longitude  Timezone  \
# 0  46227  Indianapolis    IN  39.678495  -86.12973        -5
# 1  46201  Indianapolis    IN  39.775125  -86.10839        -5
# 2  46250  Indianapolis    IN  39.905689  -86.06733        -5
# 3  46228  Indianapolis    IN  39.849474  -86.20448        -5
# 4  46224  Indianapolis    IN  39.795593  -86.25409        -5
#
#    Daylight savings time flag             geopoint
# 0                           0  39.678495,-86.12973
# 1                           0  39.775125,-86.10839
# 2                           0  39.905689,-86.06733
# 3                           0  39.849474,-86.20448
# 4                           0  39.795593,-86.25409

# %% [markdown]
# Remember, the only Zip Codes we need are 46256, 46259, 46234, 46237 and 46278.

# %%
alldata=df_data_1

# %%
alldata
# Out:
#       Zip          City State   Latitude  Longitude  Timezone  \
# 0   46227  Indianapolis    IN  39.678495 -86.129730        -5
# 1   46201  Indianapolis    IN  39.775125 -86.108390        -5
# 2   46250  Indianapolis    IN  39.905689 -86.067330        -5
# 3   46228  Indianapolis    IN  39.849474 -86.204480        -5
# 4   46224  Indianapolis    IN  39.795593 -86.254090        -5
# 5   46216  Indianapolis    IN  39.857639 -86.009480        -5
# 6   46242  Indianapolis    IN  39.779492 -86.132837        -5
# 7   46244  Indianapolis    IN  39.779492 -86.132837        -5
# 8   46231  Indianapolis    IN  39.719620 -86.331210        -5
# 9   46259  Indianapolis    IN  39.651145 -85.980730        -5
# 10  46295  Indianapolis    IN  39.779492 -86.132837        -5
# 11  46234  Indianapolis    IN  39.797622 -86.324930        -5
# 12  46221  Indianapolis    IN  39.719444 -86.221830        -5
# 13  46290  Indianapolis    IN  39.934949 -86.162620        -5
# ...

# %%
all_data=alldata[(alldata.values  == 46256)|(alldata.values  == 46259 )|(alldata.values == 46234)|(alldata.values == 46237)|(alldata.values == 46278)]

# %%
toappend = SafestFive.sort_values(by='Zipcodes')
toappend
# Out:
#                                   0  Zipcodes
# 7             W 56th St / Dandy Trl     46234
# 8  S Arlington Ave / Shelbyville Rd     46237
# 4         E 96th St / Fall Creek Rd     46256
# 5      Acton / Charle Sumac Estates     46259
# 9                     Traders Point     46278

# %%
all_data1 = all_data.sort_values(by='Zip')
all_data1
# Out:
#       Zip          City State   Latitude  Longitude  Timezone  \
# 11  46234  Indianapolis    IN  39.797622  -86.32493        -5
# 49  46237  Indianapolis    IN  39.678590  -86.08634        -5
# 28  46256  Indianapolis    IN  39.907838  -86.01405        -5
# 9   46259  Indianapolis    IN  39.651145  -85.98073        -5
# 22  46278  Indianapolis    IN  39.897920  -86.28619        -5
#
#     Daylight savings time flag             geopoint
# 11                           0  39.797622,-86.32493
# 49                           0   39.67859,-86.08634
# 28                           0  39.907838,-86.01405
# 9                            0  39.651145,-85.98073
# 22                           0   39.89792,-86.28619

# %%
Neighborhoods = ['W 56th St Dandy Trl', 'S Arlington Ave Shelbyville Rd', 'E 96th St Fall Creek Rd', 'Acton Charle Sumac Estates', 'Traders Point']

# %%
Neighborhoods
# Out:
# ['W 56th St Dandy Trl',
#  'S Arlington Ave Shelbyville Rd',
#  'E 96th St Fall Creek Rd',
#  'Acton Charle Sumac Estates',
#  'Traders Point']

# %%
all_data1['Neighborhoods'] = Neighborhoods

# %%
all_data1
# Out:
#       Zip          City State   Latitude  Longitude  Timezone  \
# 11  46234  Indianapolis    IN  39.797622  -86.32493        -5
# 49  46237  Indianapolis    IN  39.678590  -86.08634        -5
# 28  46256  Indianapolis    IN  39.907838  -86.01405        -5
# 9   46259  Indianapolis    IN  39.651145  -85.98073        -5
# 22  46278  Indianapolis    IN  39.897920  -86.28619        -5
#
#     Daylight savings time flag             geopoint  \
# 11                           0  39.797622,-86.32493
# 49                           0   39.67859,-86.08634
# 28                           0  39.907838,-86.01405
# 9                            0  39.651145,-85.98073
# 22                           0   39.89792,-86.28619
#
#                      Neighborhoods
# 11             W 56th St Dandy Trl
# 49  S Arlington Ave Shelbyville Rd
# 28         E 96th St Fall Creek Rd
# 9       Acton Charle Sumac Estates
# 22                   Traders Point

# %%
finaldata=all_data1

# %%
finaldata
# Out:
#       Zip          City State   Latitude  Longitude  Timezone  \
# 11  46234  Indianapolis    IN  39.797622  -86.32493        -5
# 49  46237  Indianapolis    IN  39.678590  -86.08634        -5
# 28  46256  Indianapolis    IN  39.907838  -86.01405        -5
# 9   46259  Indianapolis    IN  39.651145  -85.98073        -5
# 22  46278  Indianapolis    IN  39.897920  -86.28619        -5
#
#     Daylight savings time flag             geopoint  \
# 11                           0  39.797622,-86.32493
# 49                           0   39.67859,-86.08634
# 28                           0  39.907838,-86.01405
# 9                            0  39.651145,-85.98073
# 22                           0   39.89792,-86.28619
#
#                      Neighborhoods
# 11             W 56th St Dandy Trl
# 49  S Arlington Ave Shelbyville Rd
# 28         E 96th St Fall Creek Rd
# 9       Acton Charle Sumac Estates
# 22                   Traders Point

# %% [markdown]
# Now, let's add in all other necessary libraries.

# %%
# !pip install geopandas
# !pip install geopy
# Out:
# ...
#      |████████████████████████████████| 931kB 9.0MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 14.7MB 21.5MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 1.8MB 48.4MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 10.4MB 45.4MB/s eta 0:00:01
# ...

# %%
from geopy.geocoders import Nominatim

# %%
address = 'Indianapolis, Indiana'

geolocator = Nominatim(user_agent="my-application")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Indianapolis, Indiana {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Indianapolis, Indiana 39.7683331, -86.1583502.

# %%
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
# Out:
# ...
#      |████████████████████████████████| 92kB 15.3MB/s eta 0:00:01
# ...

# %%
import folium

# %% [markdown]
# Let's mark down these five safest zips over a map of Indianapolis, IND

# %%
map_kl = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, neighborhood in zip(finaldata['Latitude'], finaldata['Longitude'], finaldata['Zip']):
    label = '{}'.format(neighborhood)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7).add_to(map_kl)

# %%
map_kl
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Ok, these are pretty spread out. Let's see about the attributes now.

# %%
# save the map as HTML file
map_kl.save('map_kl.html')

# %%
# define Foursquare Credentials and Version
CLIENT_ID = 'KU4DB5D5CRFHYM2QID1VFAY4120HOHZXYLCICNYT1BYSYLWW' # your Foursquare ID
CLIENT_SECRET = 'TJGDGLWAG04ICSEIM5DCYRXWJHFSGAQPDWFX1DIGON0D2LOW' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KU4DB5D5CRFHYM2QID1VFAY4120HOHZXYLCICNYT1BYSYLWW
# CLIENT_SECRET:TJGDGLWAG04ICSEIM5DCYRXWJHFSGAQPDWFX1DIGON0D2LOW

# %%
radius = 2000
LIMIT = 100

venues = []

for lat, long, neighborhood in zip(finaldata['Latitude'], finaldata['Longitude'], finaldata['Zip']):
    
    # create the API request URL
    url = "https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}".format(
        CLIENT_ID,
        CLIENT_SECRET,
        VERSION,
        lat,
        long,
        radius, 
        LIMIT)
    
    # make the GET request
    results = requests.get(url).json()["response"]['groups'][0]['items']
    
    # return only relevant information for each nearby venue
    for venue in results:
        venues.append((
            neighborhood,
            lat, 
            long, 
            venue['venue']['name'], 
            venue['venue']['location']['lat'], 
            venue['venue']['location']['lng'],  
            venue['venue']['categories'][0]['name']))

# %%
# convert the venues list into a new DataFrame
venues_df = pd.DataFrame(venues)

# define the column names
venues_df.columns = ['Zip', 'Latitude', 'Longitude', 'VenueName', 'VenueLatitude', 'VenueLongitude', 'VenueCategory']

print(venues_df.shape)
venues_df.head()
# Out:
# (143, 7)
#      Zip   Latitude  Longitude                                   VenueName  \
# 0  46234  39.797622  -86.32493                         Westside Gymnastics
# 1  46234  39.797622  -86.32493                            B&O Trail Tansel
# 2  46234  39.797622  -86.32493                                 Dairy Queen
# 3  46234  39.797622  -86.32493  N Raceway Rd & Poppy Hill Dr  / Verona Way
# 4  46234  39.797622  -86.32493                  Golden Dragon Chinese Food
#
#    VenueLatitude  VenueLongitude       VenueCategory
# 0      39.800110      -86.327090      Gymnastics Gym
# 1      39.799245      -86.331202               Trail
# 2      39.814979      -86.320967      Ice Cream Shop
# 3      39.791177      -86.326600        Intersection
# 4      39.810267      -86.308424  Chinese Restaurant

# %%
print('There are {} unique categories.'.format(len(venues_df['VenueCategory'].unique())))
# Out:
# There are 74 unique categories.

# %%
# print out the list of categories
venues_df['VenueCategory'].unique()
# Out:
# array(['Gymnastics Gym', 'Trail', 'Ice Cream Shop', 'Intersection',
#        'Chinese Restaurant', 'Home Service', 'Music Venue',
#        'Dance Studio', 'Wine Bar', 'Golf Course', 'Food Truck',
#        'Cosmetics Shop', 'Fast Food Restaurant', 'Sandwich Place',
#        'Big Box Store', 'Mobile Phone Shop', 'American Restaurant',
#        'Japanese Restaurant', 'Steakhouse', 'Motorcycle Shop',
#        'Mexican Restaurant', 'Pharmacy', 'Coffee Shop', 'Grocery Store',
#        'Italian Restaurant', 'Pizza Place', 'Spa', 'Hardware Store',
#        'Breakfast Spot', 'Pet Store', 'Bakery', 'Department Store',
#        'Gym / Fitness Center', 'Liquor Store', 'Bar', 'Video Game Store',
#        'Gas Station', 'Outlet Store', 'Motel', 'Supermarket',
#        'Supplement Shop', 'Hotel', 'Frozen Yogurt Shop', 'Sports Bar',
#        'Salon / Barbershop', 'Clothing Store', 'Boutique', 'Bank',
#        'Video Store', 'Wings Joint', 'Furniture / Home Store',
# ...

# %% [markdown]
# From this array, the venues I need are 'Trail', 'Chinese Restaurant', 'Music Venue', 'Wine Bar', 'Food Truck', 'American Restaurant', 'Japanese Restaurant', 'Steakhouse', 'Mexican Restaurant', 'Coffee Shop', 'Italian Restaurant', 'Pizza Place', 'Breakfast Spot', 'Gym/Fitness Center', 'Bar', 'Frozen Yogurt Shop', 'Sports Bar', 'Pub', 'Shopping Mall', 'Gym', 'Café' and 'Outdoors & Recreation'.

# %%
family=venues_df[(venues_df.values  == 'Trail')|(venues_df.values  == 'Chinese Restaurant' )|(venues_df.values == 'Music Venue')|(venues_df.values == 'Wine Bar')|(venues_df.values == 'Food Truck')|(venues_df.values == 'American Restaurant')|(venues_df.values == 'Japanese Restaurant')|(venues_df.values == 'Steakhouse')|(venues_df.values == 'Mexican Restaurant')|(venues_df.values == 'Coffee Shop')|(venues_df.values == 'Italian Restaurant')|(venues_df.values == 'Pizza Place')|(venues_df.values == 'Breakfast Spot')|(venues_df.values == 'Gym/Fitness Center')|(venues_df.values == 'Bar')|(venues_df.values == 'Frozen Yogurt Shop')|(venues_df.values == 'Pub')|(venues_df.values == 'Shopping Mall')|(venues_df.values == 'Gym')|(venues_df.values == 'Café')|(venues_df.values == 'Outdoors & Recreation')]

# %%
family
# Out:
#        Zip   Latitude  Longitude                         VenueName  \
# 1    46234  39.797622  -86.32493                  B&O Trail Tansel
# 4    46234  39.797622  -86.32493        Golden Dragon Chinese Food
# 6    46234  39.797622  -86.32493                        The Studio
# 8    46234  39.797622  -86.32493                  Clermont Liquors
# 10   46234  39.797622  -86.32493                     Sweet Jeanius
# 16   46237  39.678590  -86.08634  Uno Pizzeria & Grill - Southport
# 17   46237  39.678590  -86.08634                       Hana fusion
# 18   46237  39.678590  -86.08634               LongHorn Steakhouse
# 20   46237  39.678590  -86.08634               Qdoba Mexican Grill
# 23   46237  39.678590  -86.08634  Cracker Barrel Old Country Store
# 24   46237  39.678590  -86.08634                         Starbucks
# 26   46237  39.678590  -86.08634          Carrabba's Italian Grill
# 27   46237  39.678590  -86.08634                      HotBox Pizza
# ...

# %%
Class = ['B','C','C','C','C','C','C','C','C','C','A','C','C','A','A','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','C','A','C','C','C','C','C','B','A','B']

# %%
finalfamily=family.drop(['class'],axis=1)

# %%
finalfamily.head()
# Out:
#       Zip   Latitude  Longitude                   VenueName  VenueLatitude  \
# 1   46234  39.797622  -86.32493            B&O Trail Tansel      39.799245
# 4   46234  39.797622  -86.32493  Golden Dragon Chinese Food      39.810267
# 6   46234  39.797622  -86.32493                  The Studio      39.788976
# 8   46234  39.797622  -86.32493            Clermont Liquors      39.814304
# 10  46234  39.797622  -86.32493               Sweet Jeanius      39.815070
#
#     VenueLongitude       VenueCategory Class
# 1       -86.331202               Trail     B
# 4       -86.308424  Chinese Restaurant     C
# 6       -86.305654         Music Venue     C
# 8       -86.317285            Wine Bar     C
# 10      -86.319618          Food Truck     C

# %% [markdown]
# Let's assign each one a class for colors on the map. Coffee Shops, Cafes and Bookstores will be red. Trail, Gym/Fitness Center, Gym, Outdoors/Recreation will be blue. The remainder will be green.

# %%
locations = family[['VenueLatitude', 'VenueLongitude']]
locationlist = locations.values.tolist()
len(locationlist)
# Out:
# 46

# %%
family.head()
# Out:
#       Zip   Latitude  Longitude                   VenueName  VenueLatitude  \
# 1   46234  39.797622  -86.32493            B&O Trail Tansel      39.799245
# 4   46234  39.797622  -86.32493  Golden Dragon Chinese Food      39.810267
# 6   46234  39.797622  -86.32493                  The Studio      39.788976
# 8   46234  39.797622  -86.32493            Clermont Liquors      39.814304
# 10  46234  39.797622  -86.32493               Sweet Jeanius      39.815070
#
#     VenueLongitude       VenueCategory Class class
# 1       -86.331202               Trail     B     B
# 4       -86.308424  Chinese Restaurant     C     C
# 6       -86.305654         Music Venue     C     C
# 8       -86.317285            Wine Bar     C     C
# 10      -86.319618          Food Truck     C     C

# %%
m = folium.Map(
    location=[39.7683331, -86.1583502],
    zoom_start=12,
    tiles='cartodbpositron'
)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
locations = family[['VenueLatitude', 'VenueLongitude']]
locationlist = locations.values.tolist()
len(locationlist)
Zipcodez = family['Zip']
ziplist = Zipcodez.tolist()

# %%
for point in range(0, len(locationlist)):
    folium.Marker(locationlist[point],ziplist[point]).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# let's recall that earlier zip/neighborhood dataframe we made.

# %%
finaldata
# Out:
#       Zip          City State   Latitude  Longitude  Timezone  \
# 11  46234  Indianapolis    IN  39.797622  -86.32493        -5
# 49  46237  Indianapolis    IN  39.678590  -86.08634        -5
# 28  46256  Indianapolis    IN  39.907838  -86.01405        -5
# 9   46259  Indianapolis    IN  39.651145  -85.98073        -5
# 22  46278  Indianapolis    IN  39.897920  -86.28619        -5
#
#     Daylight savings time flag             geopoint  \
# 11                           0  39.797622,-86.32493
# 49                           0   39.67859,-86.08634
# 28                           0  39.907838,-86.01405
# 9                            0  39.651145,-85.98073
# 22                           0   39.89792,-86.28619
#
#                      Neighborhoods
# 11             W 56th St Dandy Trl
# 49  S Arlington Ave Shelbyville Rd
# 28         E 96th St Fall Creek Rd
# 9       Acton Charle Sumac Estates
# 22                   Traders Point

# %% [markdown]
# Looks like we're moving to Arlington Ave!
